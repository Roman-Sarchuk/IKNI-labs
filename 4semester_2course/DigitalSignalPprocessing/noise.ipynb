# %%
import numpy as np
import matplotlib.pyplot as plt

from thinkdsp import decorate

# %%
from thinkdsp import read_wave
# filename = 'SoftMurmur/13793__soarer__north-sea.wav'
# filename = 'SoftMurmur/193335__soundman9826__rain-and-thunder.wav'
# filename = 'SoftMurmur/141251__oroborosnz__thunder-storm.wav'
# filename = 'SoftMurmur/194209__klangfabrik__rainstorm.wav'
# filename = 'SoftMurmur/105272__inchadney__strong-wind-in-the-forest.wav'
# filename = 'SoftMurmur/122117__kyster__rain-late-at-night.wav'
filename = 'SoftMurmur/127596__juskiddink__wind-in-birch-treesa-passing-sheep.wav'
# filename = 'SoftMurmur/132534__inchadney__fireplace.wav'
# filename = 'SoftMurmur/136977__audionautics__crowd-long.wav'
# filename = 'SoftMurmur/139337__felixblume__wind-is-blowing-in-the-grass-of-a-patagonian-plain-wind-is-blowing-in-the-trees-in-background-tierra-del-fuego-argentina.wav'
# filename = 'SoftMurmur/173920__matias44__murmullo-restaurante-murmur-restaurant.wav'
# filename = 'SoftMurmur/22604__martypinso__dmp010037-crickets-texas.wav'
# filename = 'SoftMurmur/56611__inchadney__morning-in-the-country.wav'
# filename = 'SoftMurmur/83986__inchadney__fireplace.wav'
wave = read_wave(filename)

# %%
wave.make_audio()

# %%
wave.plot()

# %%
segment_1 = wave.segment(start=10, duration=0.5)
segment_1.plot()

# %%
spectrum_1 = segment_1.make_spectrum() 
spectrum_1.plot(low=14, high=5000)

# %%
segment_2 = wave.segment(start=50, duration=0.5)
segment_2.plot()

# %%
spectrum_2 = segment_2.make_spectrum()
spectrum_2.plot(low=14, high=5000)

# %%
segment_3 = wave.segment(start=150, duration=0.5)
segment_3.plot()

# %%
spectrum_3 = segment_3.make_spectrum()
spectrum_3.plot(low=14, high=5000)
